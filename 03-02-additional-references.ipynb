# %%
# %%html
# <style>
#
#     h1 {color:darkblue}
#     h2 {color:purple}
#     h3 {color:#0099ff}
#     hr {
#         border: 0;
#         height: 3px;
#         background: #333;
#         background-image: linear-gradient(to right, limegreen, deepskyblue, limegreen);
#     }
# </style>
# Out:
# <style>
#
#     h1 {color:darkblue}
#     h2 {color:purple}
#     h3 {color:#0099ff}
#     hr {
#         border: 0;
#         height: 3px;
#         background: #333;
#         background-image: linear-gradient(to right, limegreen, deepskyblue, limegreen);
#     }
# </style>

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # Additional References
# * Primarily the OpenAI Agents SDK: official documentation, source and examples, the Agents API, and GPT-Live
# * OpenAI platform guides appear only where a course demo uses them (hosted tools, MCP, conversation state, models)
# * Recent articles (May–September 2026) at the end cover topics that go beyond the course notebooks

# %% [markdown]
# ## Agents SDK Documentation — Core
# https://openai.github.io/openai-agents-python/
# * [Agents SDK documentation home](https://openai.github.io/openai-agents-python/) — official docs for agents, runners, tools, handoffs, guardrails, sessions, MCP, sandbox, realtime and voice agents, and tracing.
# * [Quickstart](https://openai.github.io/openai-agents-python/quickstart/) — install the SDK, set the API key, and build a first agent with handoffs and guardrails.
# * [Configuration](https://openai.github.io/openai-agents-python/config/) — SDK-wide defaults: API key and client, Responses vs. Chat Completions API shape, tracing export, and logging.
# * [Agents](https://openai.github.io/openai-agents-python/agents/) — instructions, dynamic instructions, context, output types, model settings, hooks, cloning, and forcing tool use.
# * [Running agents](https://openai.github.io/openai-agents-python/running_agents/) — `Runner.run`, `Runner.run_sync`, `Runner.run_streamed`, run config, error handlers, and durable-execution integrations.
# * [Results](https://openai.github.io/openai-agents-python/results/) — final output, new items, raw responses, interruptions and run state, guardrail results, and usage.
# * [Streaming](https://openai.github.io/openai-agents-python/streaming/) — raw response events, run item and agent events, streaming with approvals, and cancellation.
# * [Tools](https://openai.github.io/openai-agents-python/tools/) — hosted tools, local runtime tools (`ComputerTool`, `ShellTool`, `ApplyPatchTool`), function tools, agents-as-tools, tool search, and approval gates.
# * [Guardrails](https://openai.github.io/openai-agents-python/guardrails/) — input, output, and tool guardrails for policy and topic checks.
# * [Handoffs](https://openai.github.io/openai-agents-python/handoffs/) — routing work between specialized agents, handoff inputs, and input filters.
# * [Agent orchestration](https://openai.github.io/openai-agents-python/multi_agent/) — orchestrating via the LLM (handoffs, agents-as-tools) versus orchestrating in code.
# * [Context management](https://openai.github.io/openai-agents-python/context/) — local context (`RunContextWrapper`, `ToolContext`) versus context the model can see.
# * [Human-in-the-loop](https://openai.github.io/openai-agents-python/human_in_the_loop/) — marking tools as needing approval, interruptions, and resuming runs from saved state.
# * [Usage](https://openai.github.io/openai-agents-python/usage/) — per-run token usage from the run context for cost monitoring and limits.
# * [Tracing](https://openai.github.io/openai-agents-python/tracing/) — traces and spans, custom trace processors, and third-party observability integrations.
# * [Testing](https://openai.github.io/openai-agents-python/testing/) — deterministic in-memory test utilities for agents, sandbox, realtime, and voice without model calls.
# * [Agent visualization](https://openai.github.io/openai-agents-python/visualization/) — Graphviz diagrams of agents, tools, handoffs, and MCP servers (`draw_graph`).
# * [REPL utility](https://openai.github.io/openai-agents-python/repl/) — `run_demo_loop` for interactive terminal testing with persistent history and streaming.
# * [Release process and changelog](https://openai.github.io/openai-agents-python/release/) — 0.Y.Z versioning, breaking-change policy, and the changelog.
# * [API reference](https://openai.github.io/openai-agents-python/ref/) — class-by-class reference, including extensions such as Redis/MongoDB sessions, compaction sessions, and the Codex tool.

# %% [markdown]
# ## Agents SDK Documentation — Sessions, Models, and MCP
# * [Sessions](https://openai.github.io/openai-agents-python/sessions/) — conversation history with `SQLiteSession`, OpenAI Conversations sessions, Redis, MongoDB, SQLAlchemy, Dapr, and custom implementations.
# * [SQLAlchemy session](https://openai.github.io/openai-agents-python/sessions/sqlalchemy_session/) — production session storage on any SQLAlchemy-supported database (PostgreSQL, MySQL, SQLite).
# * [Advanced SQLite session](https://openai.github.io/openai-agents-python/sessions/advanced_sqlite_session/) — SQLite session with conversation branching, per-turn usage analytics, and structured queries.
# * [Encrypted session](https://openai.github.io/openai-agents-python/sessions/encrypted_session/) — transparent encryption wrapper for any session, with automatic expiration of old items.
# * [Models](https://openai.github.io/openai-agents-python/models/) — choosing and configuring models, mixing models, retries and timeouts, and non-OpenAI providers; the default model is `gpt-5.6-luna`.
# * [Third-party adapters (LiteLLM, Any-LLM)](https://openai.github.io/openai-agents-python/models/#third-party-adapters) — `LitellmModel` and other adapters for 100+ providers.
# * [Model context protocol (MCP)](https://openai.github.io/openai-agents-python/mcp/) — hosted MCP tools, `MCPServerStreamableHttp`, `MCPServerStdio`, tool filtering, and server management.

# %% [markdown]
# ## Agents SDK Documentation — Sandbox, Realtime, and Voice Agents
# * [Sandbox agents quickstart](https://openai.github.io/openai-agents-python/sandbox_agents/) — `SandboxAgent` runs with a filesystem workspace, shell access, memory, compaction, and skills.
# * [Sandbox concepts](https://openai.github.io/openai-agents-python/sandbox/guide/) — workspaces, capabilities, tools, and how a sandbox run proceeds.
# * [Sandbox clients](https://openai.github.io/openai-agents-python/sandbox/clients/) — where sandbox work runs: local, Docker, or hosted providers via `SandboxRunConfig`.
# * [Sandbox agent memory](https://openai.github.io/openai-agents-python/sandbox/memory/) — distilling lessons from prior runs into workspace files the agent reads next time.
# * [Realtime agents quickstart](https://openai.github.io/openai-agents-python/realtime/quickstart/) — `RealtimeAgent` and `RealtimeRunner` on the Realtime API with `gpt-realtime-2.1`.
# * [Realtime agents guide](https://openai.github.io/openai-agents-python/realtime/guide/) — how the SDK's realtime layer maps onto the Realtime API and what the Python SDK adds.
# * [Realtime transport](https://openai.github.io/openai-agents-python/realtime/transport/) — server-side WebSocket versus SIP transport for realtime agents.
# * [Voice pipeline quickstart](https://openai.github.io/openai-agents-python/voice/quickstart/) — speech-to-text, agent, and text-to-speech pipeline entry point.
# * [Voice pipeline guide](https://openai.github.io/openai-agents-python/voice/pipeline/) — pipeline configuration, audio input types, and result streaming.
# * [Voice pipeline tracing](https://openai.github.io/openai-agents-python/voice/tracing/) — automatic tracing of voice pipelines and configuring it via `VoicePipelineConfig`.

# %% [markdown]
# ## Agents SDK Source, Examples, and the TypeScript SDK
# * [Agents SDK GitHub repository](https://github.com/openai/openai-agents-python) — source code, issues, and releases for the Python SDK.
# * [Agents SDK release notes](https://github.com/openai/openai-agents-python/releases) — what each release adds or breaks; the course was verified against 0.22.x.
# * [Examples index](https://openai.github.io/openai-agents-python/examples/) — official examples page that links to the GitHub examples directory.
# * [Examples source tree](https://github.com/openai/openai-agents-python/tree/main/examples) — `basic`, `tools`, `agent_patterns`, `handoffs`, `memory`, `mcp`, `hosted_mcp`, `research_bot`, `financial_research_agent`, `model_providers`, `realtime`, `voice`, `sandbox`.
# * [Research bot example](https://github.com/openai/openai-agents-python/tree/main/examples/research_bot) — planner, parallel search agents, and writer multi-agent research workflow.
# * [Financial research agent example](https://github.com/openai/openai-agents-python/tree/main/examples/financial_research_agent) — planner, search, analyst tools, writer, and verifier agents for finance use cases.
# * [Sandbox examples](https://github.com/openai/openai-agents-python/tree/main/examples/sandbox) — sandboxed-agent examples: basics, handoffs, memory, cloud backends (E2B, Modal, Daytona), and guided tutorials.
# * [Agents SDK for TypeScript](https://openai.github.io/openai-agents-js/) — the TypeScript SDK's guides: agents, sandbox agents, sessions, voice agents, tracing, and testing.
# * [Agents SDK for TypeScript repository](https://github.com/openai/openai-agents-js) — source and releases for the TypeScript SDK, which tracks the Python SDK feature by feature.

# %% [markdown]
# ## Related OpenAI Platform Guides
# * [Agents guide hub](https://developers.openai.com/api/docs/guides/agents) — OpenAI's comparison of the Responses API, the Agents SDK, and the Agents API, with links to each.
# * [Agents SDK on the platform docs](https://developers.openai.com/api/docs/guides/agents/sdk) — platform-side overview of the SDK with pages on defining agents, models, running agents, sandboxes, orchestration, guardrails and approvals, results, and observability integrations.
# * [Models](https://developers.openai.com/api/docs/models) — current catalog: GPT-6 Astra, the GPT-5.6 Sol/Terra/Luna tiers, GPT-Live 1, GPT-Realtime 2.1, and GPT Image 2.5.
# * [Reasoning models](https://developers.openai.com/api/docs/guides/reasoning) — reasoning effort settings used in `ModelSettings(reasoning={'effort': ...})`.
# * [Conversation state](https://developers.openai.com/api/docs/guides/conversation-state) — `previous_response_id`, the Conversations API, context-window management, and compaction.
# * [Conversations API reference](https://developers.openai.com/api/reference/resources/conversations) — the server-managed conversation objects behind `conversation_id`.
# * [Web search tool](https://developers.openai.com/api/docs/guides/tools-web-search) — hosted web search, agentic search, domain filtering, and citations.
# * [File search tool](https://developers.openai.com/api/docs/guides/tools-file-search) — vector stores, metadata filtering, and retrieval-augmented generation.
# * [Code Interpreter tool](https://developers.openai.com/api/docs/guides/tools-code-interpreter) — running Python in hosted containers and retrieving generated files.
# * [Computer use](https://developers.openai.com/api/docs/guides/tools-computer-use) — model-driven browser or desktop control via code execution or the `computer` tool, plus safety controls.
# * [Image generation tool](https://developers.openai.com/api/docs/guides/tools-image-generation) — image generation as a model tool: `gpt-image-2.5` models, multi-turn editing, and streaming.
# * [Image generation guide](https://developers.openai.com/api/docs/guides/image-generation) — `gpt-image-2.5-sunburst` versus `gpt-image-2.5-flare`, quality levels, sizes, and editing.
# * [Connectors and MCP servers](https://developers.openai.com/api/docs/guides/tools-connectors-mcp) — remote MCP servers and OpenAI connectors as tools, with approvals, OAuth, and tool filtering.
# * [Skills](https://developers.openai.com/api/docs/guides/tools-skills) — packaging reusable instructions and scripts as skills that `SandboxAgent`s load on demand.
# * [Programmatic tool calling](https://developers.openai.com/api/docs/guides/tools-programmatic-tool-calling) — letting the model write code that coordinates several tool calls in one step.

# %% [markdown]
# ## OpenAI Agents API (Public Beta, September 10, 2026)
# OpenAI runs the agent loop for you on the Codex harness. Reached through the OpenAI Python SDK (`client.beta.agents`), not the Agents SDK.
# * [Introducing the Agents API](https://openai.com/index/introducing-the-agents-api/) — announcement: managed sessions, context compaction, tool search, programmatic tool calling, subagents, and hosted or partner sandboxes.
# * [Agents API overview](https://developers.openai.com/api/docs/guides/agents-api/overview) — agents, environments, sessions, and events; how it compares to the Agents SDK and the Responses API.
# * [Agents API quickstart](https://developers.openai.com/api/docs/guides/agents-api/quickstart) — `client.beta.agents.sessions.create(...)` with an OpenAI-hosted sandbox and streamed events.
# * [Architecture](https://developers.openai.com/api/docs/guides/agents-api/architecture) — how the harness, sessions, sandboxes, and tools fit together.
# * [Sessions](https://developers.openai.com/api/docs/guides/agents-api/sessions) — durable sessions: creating, steering, continuing, and managing them, plus events and webhooks.
# * [Function tools](https://developers.openai.com/api/docs/guides/agents-api/tools/functions) — application-side function handlers the managed agent can call.
# * [MCP tools](https://developers.openai.com/api/docs/guides/agents-api/tools/mcp) — connecting managed agents to MCP servers.
# * [OpenAI-hosted environments](https://developers.openai.com/api/docs/guides/agents-api/environments/openai-hosted) — sandboxes OpenAI provisions for running code and working with files.
# * [Self-hosted environments](https://developers.openai.com/api/docs/guides/agents-api/environments/self-hosted) — running the agent's work on your own infrastructure or a partner sandbox provider.
# * [Multi-agent](https://developers.openai.com/api/docs/guides/agents-api/multi-agent) — subagents with independent context for parallel, delegated work.
# * [Observability and tracing](https://developers.openai.com/api/docs/guides/agents-api/observability) — monitoring managed sessions and exporting traces.
# * [Agents API examples (OpenAI Cookbook)](https://developers.openai.com/cookbook/examples/agents_api/readme) — five sample apps (incident response, Slack bot, data analyst, GitHub investigator, doc reviewer) and self-hosted sandbox patterns; September 10, 2026.

# %% [markdown]
# ## GPT-Live and Voice
# * [Getting started with GPT-Live](https://developers.openai.com/api/docs/guides/live) — full-duplex voice conversations that delegate work to a backend agent.
# * [Delegation and tools in GPT-Live](https://developers.openai.com/api/docs/guides/live-delegation) — Responses versus client delegation, `session.thinking` and `session.commentary` updates, and returning results.
# * [Prompting GPT-Live](https://developers.openai.com/api/docs/guides/live-prompting) — conversation prompts with backchannel, interruption, and delegation policies.
# * [Managing GPT-Live sessions](https://developers.openai.com/api/docs/guides/live-conversations) — session lifecycle, transcripts, usage events, and graceful close.
# * [Migrate to GPT-Live](https://developers.openai.com/api/docs/guides/live-migration) — adding a GPT-Live voice front end to an existing text agent.
# * [GPT-Live over WebSockets](https://developers.openai.com/api/docs/guides/voice-websockets?api=live) — the client and server events `source/live_voice.py` sends and handles.
# * [Live API reference](https://developers.openai.com/api/reference/resources/live) — endpoint and event reference for `client.live`.
# * [GPT-Live 1 model](https://developers.openai.com/api/docs/models/gpt-live-1) — capabilities, $0.05 per voice minute billed per second, and rate limits.
# * [Voice agents guide](https://developers.openai.com/api/docs/guides/voice-agents) — choosing between GPT-Live, the Realtime API, and a speech-to-text/text-to-speech pipeline.
# * [Realtime API guide](https://developers.openai.com/api/docs/guides/realtime) — the API behind the SDK's `RealtimeAgent`, with `gpt-realtime-2.1`; positions GPT-Live as the full-duplex alternative.
# * [GPT-Live evaluation guide (OpenAI Cookbook)](https://developers.openai.com/cookbook/examples/audio/voice_agent_evaluation) — crawl/walk/run eval harnesses for full-duplex voice agents that check delegated tool execution and application state; September 10, 2026.
# * [Building a Voice Assistant with the Agents SDK (OpenAI Cookbook)](https://developers.openai.com/cookbook/examples/agents_sdk/app_assistant_voice_agents) — the SDK voice-pipeline example (speech-to-text, agent, text-to-speech); March 2025 but still the official pipeline walkthrough.

# %% [markdown]
# ## Local Models and Model Providers
# * [LiteLLM documentation](https://docs.litellm.ai/) — routing OpenAI-style calls to many model providers; current releases require `openai` 2.x, hence the separate `deitel-openai-litellm` environment.
# * [LiteLLM Ollama provider](https://docs.litellm.ai/docs/providers/ollama) — the `ollama/` model prefix and base URL settings used with `LitellmModel`.
# * [Ollama documentation](https://docs.ollama.com/) — official docs for the local model runtime: installing, pulling models, and serving.
# * [Ollama OpenAI compatibility](https://docs.ollama.com/api/openai-compatibility) — Ollama's OpenAI-compatible endpoint, an alternative path via the SDK's `OpenAIChatCompletionsModel` without LiteLLM.
# * [How to run gpt-oss locally with Ollama (OpenAI Cookbook)](https://developers.openai.com/cookbook/articles/gpt-oss/run-locally-ollama) — running OpenAI's open-weight models locally, including an Agents SDK integration.

# %% [markdown]
# ## MCP Ecosystem
# * [Model Context Protocol documentation](https://modelcontextprotocol.io/docs/getting-started/intro) — protocol concepts, architecture, and guides for building servers and clients.
# * [MCP Python SDK](https://github.com/modelcontextprotocol/python-sdk) — official Python SDK (v2) for building MCP servers and clients.
# * [Awesome MCP Servers](https://github.com/punkpeye/awesome-mcp-servers) — curated community list of MCP servers.
# * [MCPServers.com](https://mcpservers.com/) — community directory for discovering MCP servers.
# * [mcpservers.org](https://mcpservers.org/) — additional directory, including remote servers.
# * [Microsoft Playwright MCP](https://github.com/microsoft/playwright-mcp) — reputable example of an MCP server for browser automation.

# %% [markdown]
# ## Libraries and Background Used by the Demos
# * [Playwright for Python](https://playwright.dev/python/) — browser automation library.
# * [playwright-python repository](https://github.com/microsoft/playwright-python) — source and issue tracker for the Python Playwright package.
# * [yfinance documentation](https://ranaroussi.github.io/yfinance/) — simple financial market-data package.
# * [SQLite documentation](https://www.sqlite.org/docs.html) — the database behind `SQLiteSession`.
# * [Redis documentation](https://redis.io/docs/latest/) — background for the SDK's Redis session backend.
# * [MongoDB PyMongo documentation](https://www.mongodb.com/docs/languages/python/pymongo-driver/current/) — background for the SDK's MongoDB session backend.
# * [Agent Skills standard](https://agentskills.io/) — the open `SKILL.md` standard adopted by Codex, Claude, Cursor, Copilot, and the Agents SDK's sandbox agents.
# * [Building Effective AI Agents (Anthropic)](https://www.anthropic.com/engineering/building-effective-agents) — the workflow taxonomy (routing, parallelization, orchestrator-workers, evaluator-optimizer) that the SDK's `agent_patterns` examples implement.

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# # Recent Articles on the OpenAI Agents SDK
# Selected for topics that go **beyond** the course notebooks: sandbox agents, durable execution, production sessions, evals and observability, deployment, MCP gateways, and the Agents API

# %% [markdown]
# ## From OpenAI
# * [Introducing the Agents API](https://openai.com/index/introducing-the-agents-api/) — OpenAI, September 10, 2026. Public-beta managed Codex harness: sessions, compaction, tool search, programmatic tool calling, subagents, and hosted or partner sandboxes.
# * [Agents API examples](https://developers.openai.com/cookbook/examples/agents_api/readme) — OpenAI Cookbook, September 10, 2026. Five Agents API apps (incident response, Slack bot, data analyst, GitHub investigator, doc reviewer) plus app-managed and webhook-managed self-hosted sandbox patterns.
# * [GPT-Live evaluation guide](https://developers.openai.com/cookbook/examples/audio/voice_agent_evaluation) — OpenAI Cookbook, September 10, 2026. Crawl/walk/run eval harnesses for full-duplex GPT-Live voice agents that check delegated tool execution and application state, not just transcripts.
# * [Build a ChatGPT plugin with the OpenAI Agents SDK and Amazon Bedrock AgentCore](https://developers.openai.com/cookbook/examples/partners/aws/chatgpt_agents_sdk_aws_agentcore_cookbook/notebooks/chatgpt_agents_sdk_aws_agentcore_cookbook) — Rohan Awasthi, Chuck Hernandez, Syed Ahmed, Steven McAteer (OpenAI Cookbook), September 3, 2026. Deploys an SDK agent behind a private MCP adapter via Secure MCP Tunnel, optionally on AgentCore Runtime, with dual tracing to CloudWatch and OpenAI.
# * [Combining security scanners with the Agents SDK](https://developers.openai.com/cookbook/examples/agents_sdk/security_scanners_with_agents_sdk) — OpenAI Cookbook, August 5, 2026. A security-review swarm using `Agent.as_tool()`, `tool_use_behavior` stop functions, `is_enabled` tools, approval gates, and provenance validation.
# * [Enabling Long-Term Agent Memory with Oracle AI Agent Memory](https://developers.openai.com/cookbook/examples/vector_databases/oracle_db/deep_research_openai_agents) — OpenAI Cookbook, Oracle partner entry, July 16, 2026. Implements the SDK `Session` protocol on Oracle AI Database and separates durable long-term memory tools from session replay.

# %% [markdown]
# ## OpenAI Developer Blog
# https://developers.openai.com/blog — recent posts relevant to agents, skills, and MCP.
# * [Rethinking skills and prompts for GPT-6 Astra](https://developers.openai.com/blog/rethinking-skills-and-prompts-for-gpt-6-astra) — OpenAI, September 11, 2026. Trim skill descriptions, `AGENTS.md` files, and task prompts for a more capable model; over-specified instructions now cost accuracy and context.
# * [Codex as a platform: build on the open agent harness](https://developers.openai.com/blog/codex-as-a-platform) — OpenAI, August 19, 2026. Embedding the open-source Codex harness (the loop the Agents API now hosts) in your own products via `codex exec`, the Codex SDK, and app-server.
# * [Making private MCP servers reachable without making them public](https://developers.openai.com/blog/connect-private-mcp-servers-to-openai-products) — OpenAI, June 26, 2026. Secure MCP Tunnel: an outbound-only client that lets OpenAI products call MCP servers inside a private network, with OAuth through the tunnel.

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# ## Workspace Agents
#
# * No-code AI agents that run inside ChatGPT workspaces
# * Designed for organizations to automate recurring business workflows
#     * Access approved enterprise data and connectors
#     * Execute multi-step tasks autonomously
#     * Run scheduled workflows
#     * Share agents across an organization
# * Intended for business users rather than application developers
# * Managed by workspace administrators
# * Recommended by OpenAI for natural-language workflow automation instead of code-based agent development
#
# Availability
# * ChatGPT Business
# * ChatGPT Enterprise
# * ChatGPT Edu
# * ChatGPT Teachers (where available)
#
# References
# * [Introducing workspace agents in ChatGPT](https://openai.com/index/introducing-workspace-agents-in-chatgpt/) — OpenAI's announcement of shared, Codex-powered workspace agents in ChatGPT and Slack.
# * [Workspace Agents (OpenAI Help Center)](https://help.openai.com/en/articles/20001143-chatgpt-workspace-agents-for-enterprise-and-business) — availability, permissions, and administration.

# %% [markdown]
# <hr style="height:2px; border:none; color:#000; background-color:#000;">

# %% [markdown]
# © 2026 by Deitel & Associates, Inc. All Rights Reserved.
